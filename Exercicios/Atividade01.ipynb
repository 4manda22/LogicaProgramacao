# %%
#1.
print( 3+5)
# Out:
# 8

# %%
#2.
print("olá mundo")
# Out:
# olá mundo

# %%
#3.
idade = 30
print(idade)
# Out:
# 30

# %%
#4.
x = int(input("insira o numero"))
print(x)
# Out:
# 50

# %%
#5.
#bug: falta exclamação
nome = "alice!"
print(f"olá, {nome} ")
# Out:
# olá, alice

# %%
#6.
print(7>3)
# Out:
# True

# %%
#7.
idade= int(input("digite sua idade"))
if idade >=18:
    print("maior de idade")        
else: 
    print("menor de idade")
# Out:
# maior de idade

# %%
#8.
numero= int(input("digite seu número"))
if numero >0:
    print("positivo")
else: 
    print("negativo")
# Out:
# positivo

# %%
#9.
#dica: tratativa de valores começa com valores altos primeiro
nota= float(input("Digite sua nota"))
if nota >10:
    print("invalido")
elif nota >=6 and nota <=10:
    print("Aprovado")
else:
    print("Reprovado")
# Out:
# invalido

# %%
#10.
idade= 25
if idade >=18:
    print("Maior de Idade")
else:
    print("Menor de Idade")
# Out:
# Maior de Idade
